# %% [markdown]
# 1. Тема бакалаворской работы: Разработка макета системы управления линейным пьезоактюатором. Суть работы сводилась к подключению макета с пьезоактюатором к компьютеру и работе с ним в матлабе с помощью Simulink Desktop Real-Time.
# 2. Пока что тема магистарской работы звучит как исследование максимального быстродействия работы пьезопривода. Возможно, что я изменю тему работы. Задача заключается в увеличении быстродействия пьезоактюаторов. Теория экстремального управления изучает этот вопрос.
# 3. Весь мой опыт взаимодействия с МО ограничивается прохождением 2 курсов в рамках учебы.
# 4. Знания по математике имеются, нужно лишь их немного освежить.
# 5. От курса хочется побольше практики, но также чтобы были ссылки на теорию, чтобы было понятно как реализовывать модели.
